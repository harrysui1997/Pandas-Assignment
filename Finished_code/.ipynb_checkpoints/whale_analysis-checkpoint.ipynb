# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
#Define and import all required data files
whale_returns_data = Path("Resources/whale_returns.csv")
algo_returns_data = Path("Resources/algo_returns.csv")
sp_tsx_history_data = Path("Resources/sp_tsx_history.csv")

# %%
#Setup dataframe for whale_return(wr_df), algo_return(ar_df),and sp_tsx_history(sth_df)
wr_df = pd.read_csv(whale_returns_data,index_col="Date",parse_dates= True, infer_datetime_format= True)
ar_df = pd.read_csv(algo_returns_data,index_col = "Date",parse_dates= True, infer_datetime_format= True)
sth_df = pd.read_csv(sp_tsx_history_data,index_col = "Date",parse_dates= True, infer_datetime_format= True)

# %%
# Reading whale returns
wr_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
wr_df.isnull()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                       True                True
# 2015-03-03                      False               False
# 2015-03-04                      False               False
# 2015-03-05                      False               False
# 2015-03-06                      False               False
# ...                               ...                 ...
# 2019-04-25                      False               False
# 2019-04-26                      False               False
# 2019-04-29                      False               False
# 2019-04-30                      False               False
# 2019-05-01                      False               False
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                         True                    True
# 2015-03-03                        False                   False
# ...

# %%
# Drop nulls
wr_df = wr_df.dropna()
wr_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns
ar_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
ar_df.isnull()
# Out:
#             Algo 1  Algo 2
# Date
# 2014-05-28   False    True
# 2014-05-29   False    True
# 2014-05-30   False    True
# 2014-06-02   False    True
# 2014-06-03   False    True
# ...            ...     ...
# 2019-04-25   False   False
# 2019-04-26   False   False
# 2019-04-29   False   False
# 2019-04-30   False   False
# 2019-05-01   False   False
#
# [1241 rows x 2 columns]

# %%
# Drop nulls
ar_df = ar_df.dropna()

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
sth_df.head()
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99

# %%
# Check Data Types
sth_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
# Use.replace to replace all "$" and "," with "" in Close column
sth_df["Close"] = sth_df["Close"].str.replace('$','')
sth_df["Close"] = sth_df["Close"].str.replace(',','')
# Out:
# <ipython-input-12-f7efbd430d18>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   sth_df["Close"] = sth_df["Close"].str.replace('$','')

# %%
sth_df
# Out:
#                Close
# Date
# 2012-10-01  12370.19
# 2012-10-02  12391.23
# 2012-10-03  12359.47
# 2012-10-04  12447.68
# 2012-10-05  12418.99
# ...              ...
# 2019-12-20  17118.44
# 2019-12-23  17128.71
# 2019-12-24  17180.15
# 2019-12-27  17168.21
# 2019-12-30  17098.56
#
# [1818 rows x 1 columns]

# %%
#Change the datatype from object to float
sth_df["Close"] = sth_df["Close"].astype(float)

# %%
# Calculate Daily Returns
# Set S&P TSX daily returns as "str_df"
str_df = sth_df.pct_change()
str_df
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# ...              ...
# 2019-12-20  0.003188
# 2019-12-23  0.000600
# 2019-12-24  0.003003
# 2019-12-27 -0.000695
# 2019-12-30 -0.004057
#
# [1818 rows x 1 columns]

# %%
# Drop nulls
str_df = str_df.dropna()

# %%
# Rename `Close` Column to be specific to this portfolio.
# set column as a list, and use .columns command to rename column
column = ["S&P TSX 60"]
str_df.columns = column
str_df.head()
# Out:
#             S&P TSX 60
# Date
# 2012-10-02    0.001701
# 2012-10-03   -0.002563
# 2012-10-04    0.007137
# 2012-10-05   -0.002305
# 2012-10-09   -0.011709

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
combined_df = pd.concat([wr_df,ar_df,str_df],axis = "columns", join = "inner")
combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  S&P TSX 60
# Date
# 2015-03-03 -0.000949   -0.008530
# 2015-03-04  0.002416   -0.003371
# 2015-03-05  0.004323    0.001344
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
# Use .plot to plot , and use figsize to make the plot clear
combined_df.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + combined_df).cumprod()- 1
# Plot cumulative returns
cumulative_returns.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
# Use . plot and Set kind = box to see a box plot
cumulative_returns.plot(kind = 'box',figsize = (20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
# use .std to calculate standard deviation of daily returns of all portfolios dataframe(combined.df)
daily_std = combined_df.std()
daily_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# PAULSON & CO.INC.              0.006982
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# S&P TSX 60                     0.007034
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60

print("daily standard deviation of S&P TSX 60 is " , daily_std['S&P TSX 60'])

# Determine which portfolios are riskier than the S&P TSX 60
# Use .sort_values to list all portoflio standard deviation in order, every thing above 'S&P TSX 60' have a greater standard deviation and riskier
daily_std.sort_values(ascending = False)
# Out:
# daily standard deviation of S&P TSX 60 is  0.007034167748577725
# BERKSHIRE HATHAWAY INC         0.012826
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# Algo 2                         0.008326
# SOROS FUND MANAGEMENT LLC      0.007828
# Algo 1                         0.007589
# S&P TSX 60                     0.007034
# PAULSON & CO.INC.              0.006982
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
# use daily standard deviation * numpy function np.sqrt(252) to calculate annualized standard deviation
annual_std = daily_std * np.sqrt(252)
annual_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.124259
# PAULSON & CO.INC.              0.110841
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# Algo 1                         0.120470
# Algo 2                         0.132177
# S&P TSX 60                     0.111664
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for for all portfolios using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
# use .rolling and set window = 21 , and then calculate the standard deviation use .std
rolling_std = combined_df.rolling(window = 21).std()
# Plot the rolling standard deviation
rolling_std.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation = combined_df.corr()
# Display de correlation matrix
# First import seaborn and use heatmap function to display correlation matrix
import seaborn as sns
sns.heatmap(correlation,vmin = -1, vmax = 1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio
# In this case I will choose Algo 2 and compare the covariance of SP 60 TSX
covariance = combined_df['Algo 2'].cov(combined_df['S&P TSX 60'])
print("covariance of Algo 2 to SP 60 TSX is ",covariance)

# Calculate variance of S&P TSX
# Use .var 
variance = combined_df['Algo 2'].var()
print ("variance of Algo 2 is " ,variance)

# Computing beta
beta = covariance/variance
print('Beta is ', beta)
# Out:
# covariance of Algo 2 to SP 60 TSX is  4.3187044300842574e-05
# variance of Algo 2 is  6.932827072786364e-05
# Beta is  0.622935547756066

# %%
# Plot beta trend
# calculate the rolling covariance and rolling variance with window of 60
rolling_covariance =combined_df['Algo 2'].rolling(window=60).cov(combined_df['S&P TSX 60'])
rolling_variance = combined_df['Algo 2'].rolling(window=60).var()
beta = rolling_covariance/rolling_variance
beta.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
times = combined_df.index.date
combined_df.ewm(halflife= "21 days", times =pd.DatetimeIndex(times)).mean()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.000511           -0.000802
# 2015-03-05                   0.001718            0.000878
# 2015-03-06                  -0.000808           -0.000291
# 2015-03-09                  -0.000496            0.000724
# ...                               ...                 ...
# 2019-04-25                   0.001442           -0.000019
# 2019-04-26                   0.001751            0.000404
# 2019-04-29                   0.001727            0.000516
# 2019-04-30                   0.001583            0.000386
# 2019-05-01                   0.001234            0.000305
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.001532               -0.001089 -0.005320
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
# Sharpe Ratios = (Return of the portfolios (combined.df) - Risk free return (not given))*252 Trading Days / standard deviation of portfolio(annual_std)
sharpe_ratio = (combined_df.mean()*252)/annual_std

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratio.plot(kind='bar',figsize = (20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# In terms of Returns, Both Algorithmic strategies have greater returns than the market, Algorithmic strategy 1 has a similar cumulative return rate as the whales portfolios and Algorithmic strategy 2 outperform all whales portfolios dramatically.
#
# In terms of Risk, Algo1 have low correlation with the market and other whale portfolios; Algo 2 has high correlation with market which makes the strategy risky when the market is performing poor.In addition, Algo 2 has a less-than-one beta in comparison to the market, which indicates the volatility of Algo 2 portoflio is lower than the market. In terms of sharpe ratio, only Algo 1 portofolio has a sharpe ratio greater than one, which indicates that it provides excessive returns relative to its volatility.
#
#
# In my opinion, Both algorithmic strategies have their own advantages compared with the market and whales portfolios. Algorithmic strategies one provide a better risk management with an close to market return, while algorithmic strategy two provides a better return along with a high correlation with the market.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P TSX 60 index.
#
# * `SHOP` - [Shopify Inc](https://en.wikipedia.org/wiki/Shopify)
#
# * `OTEX` - [Open Text Corporation](https://en.wikipedia.org/wiki/OpenText)
#
# * `L` - [Loblaw Companies Limited](https://en.wikipedia.org/wiki/Loblaw_Companies)

# %%
# Reading data from 1st stock
shop_data = Path("Resources/shop_historical.csv")
shop_df = pd.read_csv(shop_data,index_col="Date",parse_dates= True, infer_datetime_format= True)

# %%
# Reading data from 2nd stock
otex_data = Path("Resources/otex_historical.csv")
otex_df = pd.read_csv(otex_data,index_col="Date",parse_dates= True, infer_datetime_format= True)

# %%
# Reading data from 3rd stock
l_data = Path("Resources/l_historical.csv")
l_df = pd.read_csv(l_data,index_col="Date",parse_dates= True, infer_datetime_format= True)

# %%
# Combine all stocks in a single DataFrame
combined_df2 = pd.concat([shop_df,otex_df,l_df],axis = "columns", join = "inner")
combined_df2
# Out:
#            Symbol   Close Symbol  Close Symbol  Close
# Date
# 2018-01-02   SHOP  132.06   OTEX  43.58      L  57.99
# 2018-01-03   SHOP  135.15   OTEX  43.07      L  57.41
# 2018-01-04   SHOP  137.46   OTEX  42.91      L  57.42
# 2018-01-05   SHOP  137.26   OTEX  42.57      L  57.42
# 2018-01-08   SHOP  139.51   OTEX  42.16      L  56.86
# ...           ...     ...    ...    ...    ...    ...
# 2019-12-20   SHOP  513.22   OTEX  58.68      L  67.90
# 2019-12-23   SHOP  511.62   OTEX  57.89      L  67.68
# 2019-12-24   SHOP  525.39   OTEX  57.44      L  67.67
# 2019-12-27   SHOP  534.76   OTEX  57.70      L  67.78
# 2019-12-30   SHOP  517.79   OTEX  57.19      L  67.33
#
# [501 rows x 6 columns]

# %%
# Reset Date index
#Completed in previous steps

# %%
# Drop all the Symbol Columns and change "Close" columns name to their Symbol
combined_df2 = combined_df2.drop(columns = ["Symbol"])

# %%
# Reorganize portfolio data by having a column per symbol

columns = ['SHOP', 'OTEX', 'L']
combined_df2.columns = columns
combined_df2
# Out:
#               SHOP   OTEX      L
# Date
# 2018-01-02  132.06  43.58  57.99
# 2018-01-03  135.15  43.07  57.41
# 2018-01-04  137.46  42.91  57.42
# 2018-01-05  137.26  42.57  57.42
# 2018-01-08  139.51  42.16  56.86
# ...            ...    ...    ...
# 2019-12-20  513.22  58.68  67.90
# 2019-12-23  511.62  57.89  67.68
# 2019-12-24  525.39  57.44  67.67
# 2019-12-27  534.76  57.70  67.78
# 2019-12-30  517.79  57.19  67.33
#
# [501 rows x 3 columns]

# %%
# Calculate daily returns
#Use pct_change function to calculate daily returns
daily_returns2 = combined_df2.pct_change()

# Drop NAs
# Use .dropna function to delete all the null values
daily_returns2 = daily_returns2.dropna()
# Display sample data
daily_returns2.head()
# Out:
#                 SHOP      OTEX         L
# Date
# 2018-01-03  0.023398 -0.011703 -0.010002
# 2018-01-04  0.017092 -0.003715  0.000174
# 2018-01-05 -0.001455 -0.007924  0.000000
# 2018-01-08  0.016392 -0.009631 -0.009753
# 2018-01-09 -0.011254 -0.000712  0.008969

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
portfolio_return = daily_returns2.dot(weights)
# Display sample data
portfolio_return
# Out:
# Date
# 2018-01-03    0.000565
# 2018-01-04    0.004517
# 2018-01-05   -0.003126
# 2018-01-08   -0.000997
# 2018-01-09   -0.000999
#                 ...
# 2019-12-20    0.007495
# 2019-12-23   -0.006607
# 2019-12-24    0.006331
# 2019-12-27    0.007995
# 2019-12-30   -0.015737
# Length: 500, dtype: float64

# %%
#Cumulative Returns for my portfolio
cumulative_returns2 = (1 + portfolio_return).cumprod()- 1
cumulative_returns2.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
combined_df["MY PORTFOLIO"] = portfolio_return
combined_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-01-03                   0.004658            0.000027
# 2018-01-04                  -0.000914            0.004196
# 2018-01-05                   0.004072            0.000823
# 2018-01-08                   0.004473           -0.003739
# 2018-01-09                  -0.001028            0.000872
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-01-03                     0.001979                0.005676 -0.000890
# 2018-01-04                     0.010743                0.004065 -0.000914
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
combined_df = combined_df.dropna()

# %%
combined_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-01-03                   0.004658            0.000027
# 2018-01-04                  -0.000914            0.004196
# 2018-01-05                   0.004072            0.000823
# 2018-01-08                   0.004473           -0.003739
# 2018-01-09                  -0.001028            0.000872
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-01-03                     0.001979                0.005676 -0.000890
# 2018-01-04                     0.010743                0.004065 -0.000914
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
annualized_std2 = combined_df.std()*np.sqrt(252)
annualized_std2
# Out:
# SOROS FUND MANAGEMENT LLC      0.145675
# PAULSON & CO.INC.              0.114343
# TIGER GLOBAL MANAGEMENT LLC    0.219833
# BERKSHIRE HATHAWAY INC         0.227445
# Algo 1                         0.120028
# Algo 2                         0.137664
# S&P TSX 60                     0.099121
# MY PORTFOLIO                   0.224346
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
rolling_std2 = combined_df.rolling(window = 21).std()
# Plot rolling standard deviation
rolling_std2.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
correlation2 = combined_df.corr()
import seaborn as sns
sns.heatmap(correlation2,vmin = -1, vmax = 1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate the beta for my portfolio
covariance_mp = combined_df['MY PORTFOLIO'].cov(combined_df['S&P TSX 60'])
variance_mp = combined_df['MY PORTFOLIO'].var()
beta_mp = covariance_mp / variance_mp
print("Beta for my portfolio is " ,beta_mp)
# Out:
# Beta for my portfolio is  0.25591592175809463

# %%
rolling_covariance =combined_df['Algo 2'].rolling(window=60).cov(combined_df['S&P TSX 60'])
rolling_variance = combined_df['Algo 2'].rolling(window=60).var()
beta = rolling_covariance/rolling_variance
beta.plot()

# %%
#Plot the 60-day Rolling Beta for my portfolio to S&P 60 TSX
rolling_covariance_mp =combined_df['MY PORTFOLIO'].rolling(window=60).cov(combined_df['S&P TSX 60'])
rolling_variance_mp = combined_df['MY PORTFOLIO'].rolling(window=60).var()
beta_rolling_mp = rolling_covariance_mp/rolling_variance_mp
beta_rolling_mp.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios
sharpe_ratio2 = (combined_df.mean()*252)/annualized_std2

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratio2.plot(kind = 'bar', figsize = (20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %% [markdown]
# In my opinion, my portofilio is better than both algorithmic strategies in the following ways. First, my portfolio generates similar amount of returns as the Algo 2 portfolio, which is much greater than other whales portfolios and the market. Second, the portfolio has a small beta compared to the market, which indicates a small volatility and hence less risk when market is influenced dramatically. Lastly, the sharpe ratio for my portfolio is much greater than one which also indicates an excellent return compared to its volatility. However, this conclusion is not definitive since it has less years data for comparsion.
